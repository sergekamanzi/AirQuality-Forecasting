# %% [markdown]
# <a href="https://colab.research.google.com/github/sergekamanzi/AirQuality-Forecasting/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import os

# %%
# Load the datasets
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %% [markdown]
# #Data Exploration

# %%
# Inspecting the first few rows of the training dataset
print("Training Data Overview:")
print(train.head())
# Out:
# Training Data Overview:
#    No      DEWP      TEMP      PRES       Iws        Is        Ir  \
# 0   1 -1.580878 -1.922250  0.443328 -0.441894 -0.069353 -0.137667
# 1   2 -1.580878 -2.004228  0.345943 -0.379306 -0.069353 -0.137667
# 2   3 -1.580878 -1.922250  0.248559 -0.343514 -0.069353 -0.137667
# 3   4 -1.580878 -2.168183  0.248559 -0.280926 -0.069353 -0.137667
# 4   5 -1.511594 -2.004228  0.151174 -0.218339 -0.069353 -0.137667
#
#               datetime   cbwd_NW   cbwd_SE   cbwd_cv  pm2.5
# 0  2010-01-01 00:00:00  1.448138 -0.732019 -0.522096    NaN
# 1  2010-01-01 01:00:00  1.448138 -0.732019 -0.522096    NaN
# 2  2010-01-01 02:00:00  1.448138 -0.732019 -0.522096    NaN
# 3  2010-01-01 03:00:00  1.448138 -0.732019 -0.522096    NaN
# 4  2010-01-01 04:00:00  1.448138 -0.732019 -0.522096    NaN

# %%
# Display column names
print("\nColumn Names:")
print(train.columns)
# Out:
# Column Names:
# Index(['No', 'DEWP', 'TEMP', 'PRES', 'Iws', 'Is', 'Ir', 'datetime', 'cbwd_NW',
#        'cbwd_SE', 'cbwd_cv', 'pm2.5'],
#       dtype='object')

# %%
# Check for missing values
print("\nMissing Values in Train:")
print(train.isnull().sum())
print("\nMissing Values in Test:")
print(test.isnull().sum())
# Out:
# Missing Values in Train:
# No             0
# DEWP           0
# TEMP           0
# PRES           0
# Iws            0
# Is             0
# Ir             0
# datetime       0
# cbwd_NW        0
# cbwd_SE        0
# cbwd_cv        0
# pm2.5       1921
# dtype: int64
#
# Missing Values in Test:
# No          0
# DEWP        0
# TEMP        0
# PRES        0
# Iws         0
# Is          0
# Ir          0
# datetime    0
# cbwd_NW     0
# cbwd_SE     0
# cbwd_cv     0
# dtype: int64

# %%
# Summary statistics
print("\nTraining Data Summary:")
print(train.describe())
# Out:
# Training Data Summary:
#                  No          DEWP          TEMP          PRES           Iws  \
# count  30676.000000  30676.000000  30676.000000  30676.000000  30676.000000
# mean   15338.500000     -0.029431     -0.062712      0.013612      0.030542
# std     8855.542765      0.994087      1.015193      1.008991      1.018337
# min        1.000000     -2.135153     -2.578070     -2.380821     -0.468688
# 25%     7669.750000     -0.888034     -0.938521     -0.822670     -0.441894
# 50%    15338.500000     -0.056622      0.045209     -0.043595     -0.352512
# 75%    23007.250000      0.913358      0.864984      0.832865      0.005216
# max    30676.000000      1.814055      2.340578      2.877939     11.231956
#
#                  Is            Ir       cbwd_NW       cbwd_SE       cbwd_cv  \
# count  30676.000000  30676.000000  30676.000000  30676.000000  30676.000000
# mean       0.016992      0.011253      0.016193      0.005833     -0.025008
# std        1.087278      1.063811      1.006001      1.001847      0.982122
# min       -0.069353     -0.137667     -0.690542     -0.732019     -0.522096
# 25%       -0.069353     -0.137667     -0.690542     -0.732019     -0.522096
# 50%       -0.069353     -0.137667     -0.690542     -0.732019     -0.522096
# 75%       -0.069353     -0.137667      1.448138      1.366085     -0.522096
# max       35.439859     25.288745      1.448138      1.366085      1.915355
#
#               pm2.5
# count  28755.000000
# mean     100.793427
# std       93.144433
# min        0.000000
# 25%       29.000000
# 50%       75.000000
# 75%      142.000000
# max      994.000000

# %%
# Visualize PM2.5 distribution
plt.figure(figsize=(10, 6))
plt.hist(train['pm2.5'].dropna(), bins=50, color='blue', alpha=0.7)
plt.title('Distribution of PM2.5 Concentrations')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('Frequency')
plt.show()

# Plot PM2.5 over time (subset for clarity)
plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(train['datetime'][:1000]), train['pm2.5'][:1000], color='green')
plt.title('PM2.5 Concentrations Over Time (First 1000 Entries)')
plt.xlabel('Date')
plt.ylabel('PM2.5 (µg/m³)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Data Preprocessing

# %%
# Convert 'datetime' to datetime format
train['datetime'] = pd.to_datetime(train['datetime'])
test['datetime'] = pd.to_datetime(test['datetime'])

# %%
# Set 'datetime' as index
train.set_index('datetime', inplace=True)
test.set_index('datetime', inplace=True)

# %%
# Handle missing values by forward filling, then mean if needed
train.fillna(method='ffill', inplace=True)
train.fillna(train.mean(), inplace=True)
test.fillna(method='ffill', inplace=True)
test.fillna(test.mean(), inplace=True)
# Out:
# <ipython-input-11-9de9f9bb45ec>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   train.fillna(method='ffill', inplace=True)
# <ipython-input-11-9de9f9bb45ec>:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test.fillna(method='ffill', inplace=True)

# %%
# Separate features and target
X_train = train.drop(['pm2.5', 'No'], axis=1)
y_train = train['pm2.5']
X_test = test.drop(['No'], axis=1)

# %%
# Normalize features
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create sequences for LSTM (e.g., use 24 hours as sequence length)
def create_sequences(data, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(target[i + seq_length])
    return np.array(X), np.array(y)

seq_length = 24  # 24-hour sequences
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train.values, seq_length)

# %% [markdown]
# # Prepare test data sequences

# %%
# For each test sample, use the last seq_length available data points
X_test_seq = []
test_indices = test.index[-len(X_test_scaled):]  # Store indices for submission
for i in range(len(X_test_scaled)):
    start_idx = max(0, i - seq_length + 1)
    sequence = X_test_scaled[start_idx:i + 1]
    if len(sequence) < seq_length:
        # Pad with zeros if sequence is shorter than seq_length
        padding = np.zeros((seq_length - len(sequence), X_test_scaled.shape[1]))
        sequence = np.vstack((padding, sequence))
    X_test_seq.append(sequence)
X_test_seq = np.array(X_test_seq)

# %% [markdown]
# #Model Design

# %%
# Define LSTM model
model = Sequential([
    LSTM(64, activation='relu', input_shape=(seq_length, X_train.shape[1]), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model with custom learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(
    optimizer=optimizer,
    loss='mse',
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Display model architecture
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 24, 64)         │        18,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,905 (124.63 KB)
#  Trainable params: 31,905 (124.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Training

# %%
# Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - loss: 10334.6934 - root_mean_squared_error: 100.7764 - val_loss: 9635.1924 - val_root_mean_squared_error: 98.1590
# Epoch 2/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 6153.3560 - root_mean_squared_error: 78.4109 - val_loss: 7950.1626 - val_root_mean_squared_error: 89.1637
# Epoch 3/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 5348.5010 - root_mean_squared_error: 73.1280 - val_loss: 7128.5156 - val_root_mean_squared_error: 84.4305
# Epoch 4/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - loss: 5197.9785 - root_mean_squared_error: 72.0940 - val_loss: 7234.6660 - val_root_mean_squared_error: 85.0568
# Epoch 5/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - loss: 4883.9014 - root_mean_squared_error: 69.8790 - val_loss: 7101.6479 - val_root_mean_squared_error: 84.2713
# Epoch 6/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 4625.6455 - root_mean_squared_error: 68.0005 - val_loss: 7209.4287 - val_root_mean_squared_error: 84.9084
# Epoch 7/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - loss: 4340.8384 - root_mean_squared_error: 65.8647 - val_loss: 6889.2949 - val_root_mean_squared_error: 83.0018
# Epoch 8/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 4358.0806 - root_mean_squared_error: 65.9846 - val_loss: 8047.5361 - val_root_mean_squared_error: 89.7081
# Epoch 9/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - loss: 4282.3457 - root_mean_squared_error: 65.4304 - val_loss: 6773.1948 - val_root_mean_squared_error: 82.2994
# Epoch 10/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 4043.9348 - root_mean_squared_error: 63.5700 - val_loss: 8047.8774 - val_root_mean_squared_error: 89.7100
# Epoch 11/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 3960.0454 - root_mean_squared_error: 62.9190 - val_loss: 6799.7920 - val_root_mean_squared_error: 82.4609
# Epoch 12/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 3987.6677 - root_mean_squared_error: 63.1387 - val_loss: 6658.2168 - val_root_mean_squared_error: 81.5979
# Epoch 13/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - loss: 3807.8860 - root_mean_squared_error: 61.7050 - val_loss: 6771.9785 - val_root_mean_squared_error: 82.2920
# Epoch 14/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 36ms/step - loss: 3847.9976 - root_mean_squared_error: 61.9963 - val_loss: 6856.5820 - val_root_mean_squared_error: 82.8045
# Epoch 15/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 3582.9272 - root_mean_squared_error: 59.8462 - val_loss: 6183.2651 - val_root_mean_squared_error: 78.6337
# Epoch 16/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 3517.0056 - root_mean_squared_error: 59.2975 - val_loss: 5901.4541 - val_root_mean_squared_error: 76.8209
# Epoch 17/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 3702.0942 - root_mean_squared_error: 60.8274 - val_loss: 7183.0317 - val_root_mean_squared_error: 84.7528
# Epoch 18/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 3399.2712 - root_mean_squared_error: 58.2950 - val_loss: 5837.7217 - val_root_mean_squared_error: 76.4050
# Epoch 19/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 3292.0771 - root_mean_squared_error: 57.3729 - val_loss: 6088.7061 - val_root_mean_squared_error: 78.0302
# Epoch 20/20
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - loss: 3307.7646 - root_mean_squared_error: 57.5071 - val_loss: 6185.3481 - val_root_mean_squared_error: 78.6470

# %% [markdown]
# #Results and Visualization

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss (MSE)')
plt.plot(history.history['val_loss'], label='Validation Loss (MSE)')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

# %%
# Calculate final training RMSE
train_predictions = model.predict(X_train_seq)
train_rmse = np.sqrt(np.mean((y_train_seq - train_predictions.flatten())**2))
print(f"Final Training RMSE: {train_rmse}")
# Out:
# 958/958 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step
# Final Training RMSE: 60.87054465549706

# %% [markdown]
# #Predictions

# %%
# Make predictions on test set
predictions = model.predict(X_test_seq)

# Ensure predictions are non-negative and handle NaN
predictions = np.nan_to_num(predictions, nan=0.0)
predictions = np.maximum(predictions, 0)

# Convert predictions to integers
predictions = np.round(predictions).astype(int)

# Prepare submission file
submission = pd.DataFrame({
    'row ID': pd.to_datetime(test_indices).strftime('%Y-%m-%d %-H:%M:%S'),
    'pm2.5': predictions.flatten()
})

# Sort by 'row ID'
submission = submission.sort_values(by='row ID')

# Save submission in the same directory as input files
output_path = '/content/submission.csv'
submission.to_csv(output_path, index=False)
print(f"Submission file saved as '{output_path}'")
# Out:
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step
# Submission file saved as '/content/submission.csv'
